# %%
#python packages 
import pandas as pd
import numpy as np

# %%
#importing the dataset
labour1_df =  pd.read_csv("14100082.CSV")
labour2_df =  pd.read_csv("14100083.CSV")
labour3_df =  pd.read_csv("14100084.CSV")
labour4_df =  pd.read_csv("14100085.CSV")
labour5_df =  pd.read_csv("14100086.CSV")
labour6_df =  pd.read_csv("14100087.CSV")
labour7_df =  pd.read_csv("14100088.CSV")
labour8_df =  pd.read_csv("14100089.CSV")

# %%
labour1_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status',
#        'Labour force characteristics', 'Age group', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour2_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status',
#        'Labour force characteristics', 'Age group', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour3_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status',
#        'Labour force characteristics', 'Sex', 'Age group', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour4_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status',
#        'Labour force characteristics', 'Sex', 'Age group', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour5_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status',
#        'Educational attainment', 'Labour force characteristics', 'Sex',
#        'Age group', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR',
#        'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour6_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status',
#        'Educational attainment', 'Labour force characteristics', 'Sex',
#        'Age group', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR',
#        'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour7_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status', 'Country of birth',
#        'Labour force characteristics', 'Sex', 'Age group', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour8_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Immigrant status', 'Country of birth',
#        'Labour force characteristics', 'Sex', 'Age group', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
labour1_df.describe()
# Out:
#               UOM_ID      SCALAR_ID          VALUE  SYMBOL  TERMINATED  \
# count  395520.000000  395520.000000  382132.000000     0.0         0.0
# mean      246.900000       2.100000     463.014091     NaN         NaN
# std         3.207807       1.374774    1619.366097     NaN         NaN
# min       242.000000       0.000000       0.200000     NaN         NaN
# 25%       242.000000       0.000000      13.000000     NaN         NaN
# 50%       249.000000       3.000000      69.000000     NaN         NaN
# 75%       249.000000       3.000000     233.900000     NaN         NaN
# max       249.000000       3.000000   32208.400000     NaN         NaN
#
#        DECIMALS
# count  395520.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
labour2_df.describe()
# Out:
#            REF_DATE        UOM_ID     SCALAR_ID         VALUE  SYMBOL  \
# count  32640.000000  32640.000000  32640.000000  31575.000000     0.0
# mean    2014.000000    246.900000      2.100000    461.541593     NaN
# std        4.899055      3.207852      1.374794   1615.564915     NaN
# min     2006.000000    242.000000      0.000000      0.200000     NaN
# 25%     2010.000000    242.000000      0.000000     12.700000     NaN
# 50%     2014.000000    249.000000      3.000000     68.900000     NaN
# 75%     2018.000000    249.000000      3.000000    232.700000     NaN
# max     2022.000000    249.000000      3.000000  31772.100000     NaN
#
#        TERMINATED  DECIMALS
# count         0.0   32640.0
# mean          NaN       1.0
# std           NaN       0.0
# min           NaN       1.0
# 25%           NaN       1.0
# 50%           NaN       1.0
# 75%           NaN       1.0
# max           NaN       1.0

# %%
labour3_df.describe()
# Out:
#               UOM_ID      SCALAR_ID          VALUE  SYMBOL  TERMINATED  \
# count  148320.000000  148320.000000  147833.000000     0.0         0.0
# mean      246.900000       2.100000    1184.764392     NaN         NaN
# std         3.207814       1.374777    2799.532017     NaN         NaN
# min       242.000000       0.000000       1.500000     NaN         NaN
# 25%       242.000000       0.000000      40.400000     NaN         NaN
# 50%       249.000000       3.000000      97.300000     NaN         NaN
# 75%       249.000000       3.000000     930.400000     NaN         NaN
# max       249.000000       3.000000   32208.400000     NaN         NaN
#
#        DECIMALS
# count  148320.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
labour4_df.describe()
# Out:
#           REF_DATE        UOM_ID     SCALAR_ID         VALUE  SYMBOL  \
# count  12240.00000  12240.000000  12240.000000  12216.000000     0.0
# mean    2014.00000    246.900000      2.100000   1180.562713     NaN
# std        4.89918      3.207934      1.374829   2792.787651     NaN
# min     2006.00000    242.000000      0.000000      1.500000     NaN
# 25%     2010.00000    242.000000      0.000000     40.200000     NaN
# 50%     2014.00000    249.000000      3.000000     95.500000     NaN
# 75%     2018.00000    249.000000      3.000000    924.300000     NaN
# max     2022.00000    249.000000      3.000000  31772.100000     NaN
#
#        TERMINATED  DECIMALS
# count         0.0   12240.0
# mean          NaN       1.0
# std           NaN       0.0
# min           NaN       1.0
# 25%           NaN       1.0
# 50%           NaN       1.0
# 75%           NaN       1.0
# max           NaN       1.0

# %%
labour5_df.describe()
# Out:
#               UOM_ID      SCALAR_ID          VALUE  SYMBOL  TERMINATED  \
# count  355968.000000  355968.000000  352402.000000     0.0         0.0
# mean      246.375000       1.875000     635.264167     NaN         NaN
# std         3.388865       1.452371    1862.373226     NaN         NaN
# min       242.000000       0.000000       1.400000     NaN         NaN
# 25%       242.000000       0.000000      30.300000     NaN         NaN
# 50%       249.000000       3.000000      77.700000     NaN         NaN
# 75%       249.000000       3.000000     341.475000     NaN         NaN
# max       249.000000       3.000000   32208.400000     NaN         NaN
#
#        DECIMALS
# count  355968.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
labour6_df.describe()
# Out:
#            REF_DATE        UOM_ID     SCALAR_ID         VALUE  SYMBOL  \
# count  29376.000000  29376.000000  29376.000000  29139.000000     0.0
# mean    2014.000000    246.375000      1.875000    632.856042     NaN
# std        4.899063      3.388918      1.452393   1857.255140     NaN
# min     2006.000000    242.000000      0.000000      1.500000     NaN
# 25%     2010.000000    242.000000      0.000000     30.100000     NaN
# 50%     2014.000000    249.000000      3.000000     77.400000     NaN
# 75%     2018.000000    249.000000      3.000000    338.550000     NaN
# max     2022.000000    249.000000      3.000000  31772.100000     NaN
#
#        TERMINATED  DECIMALS
# count         0.0   29376.0
# mean          NaN       1.0
# std           NaN       0.0
# min           NaN       1.0
# 25%           NaN       1.0
# 50%           NaN       1.0
# 75%           NaN       1.0
# max           NaN       1.0

# %%
labour7_df.describe()
# Out:
#               UOM_ID      SCALAR_ID          VALUE  SYMBOL  TERMINATED  \
# count  326304.000000  326304.000000  319630.000000     0.0         0.0
# mean      246.375000       1.875000     698.372025     NaN         NaN
# std         3.388866       1.452371    2297.144474     NaN         NaN
# min       242.000000       0.000000       1.500000     NaN         NaN
# 25%       242.000000       0.000000      26.600000     NaN         NaN
# 50%       249.000000       3.000000      74.200000     NaN         NaN
# 75%       249.000000       3.000000     250.700000     NaN         NaN
# max       249.000000       3.000000   32208.400000     NaN         NaN
#
#        DECIMALS
# count  326304.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
labour8_df.describe()
# Out:
#           REF_DATE        UOM_ID     SCALAR_ID         VALUE  SYMBOL  \
# count  26928.00000  26928.000000  26928.000000  26430.000000     0.0
# mean    2014.00000    246.375000      1.875000    695.693401     NaN
# std        4.89907      3.388923      1.452396   2291.970136     NaN
# min     2006.00000    242.000000      0.000000      1.500000     NaN
# 25%     2010.00000    242.000000      0.000000     26.400000     NaN
# 50%     2014.00000    249.000000      3.000000     73.850000     NaN
# 75%     2018.00000    249.000000      3.000000    249.300000     NaN
# max     2022.00000    249.000000      3.000000  31772.100000     NaN
#
#        TERMINATED  DECIMALS
# count         0.0   26928.0
# mean          NaN       1.0
# std           NaN       0.0
# min           NaN       1.0
# 25%           NaN       1.0
# 50%           NaN       1.0
# 75%           NaN       1.0
# max           NaN       1.0

# %%
print(labour1_df.isnull().sum())
# Out:
# REF_DATE                             0
# GEO                                  0
# DGUID                            24720
# Immigrant status                     0
# Labour force characteristics         0
# Age group                            0
# UOM                                  0
# UOM_ID                               0
# SCALAR_FACTOR                        0
# SCALAR_ID                            0
# VECTOR                               0
# COORDINATE                           0
# VALUE                            13388
# STATUS                          382132
# SYMBOL                          395520
# TERMINATED                      395520
# DECIMALS                             0
# dtype: int64

# %%
print(labour2_df.isnull().sum())
# Out:
# REF_DATE                            0
# GEO                                 0
# DGUID                            2040
# Immigrant status                    0
# Labour force characteristics        0
# Age group                           0
# UOM                                 0
# UOM_ID                              0
# SCALAR_FACTOR                       0
# SCALAR_ID                           0
# VECTOR                              0
# COORDINATE                          0
# VALUE                            1065
# STATUS                          31575
# SYMBOL                          32640
# TERMINATED                      32640
# DECIMALS                            0
# dtype: int64

# %%
print(labour3_df.isnull().sum())
# Out:
# REF_DATE                             0
# GEO                                  0
# DGUID                                0
# Immigrant status                     0
# Labour force characteristics         0
# Sex                                  0
# Age group                            0
# UOM                                  0
# UOM_ID                               0
# SCALAR_FACTOR                        0
# SCALAR_ID                            0
# VECTOR                               0
# COORDINATE                           0
# VALUE                              487
# STATUS                          147833
# SYMBOL                          148320
# TERMINATED                      148320
# DECIMALS                             0
# dtype: int64

# %%
print(labour4_df.isnull().sum())
# Out:
# REF_DATE                            0
# GEO                                 0
# DGUID                               0
# Immigrant status                    0
# Labour force characteristics        0
# Sex                                 0
# Age group                           0
# UOM                                 0
# UOM_ID                              0
# SCALAR_FACTOR                       0
# SCALAR_ID                           0
# VECTOR                              0
# COORDINATE                          0
# VALUE                              24
# STATUS                          12216
# SYMBOL                          12240
# TERMINATED                      12240
# DECIMALS                            0
# dtype: int64

# %%
print(labour5_df.isnull().sum())
# Out:
# REF_DATE                             0
# GEO                                  0
# DGUID                                0
# Immigrant status                     0
# Educational attainment               0
# Labour force characteristics         0
# Sex                                  0
# Age group                            0
# UOM                                  0
# UOM_ID                               0
# SCALAR_FACTOR                        0
# SCALAR_ID                            0
# VECTOR                               0
# COORDINATE                           0
# VALUE                             3566
# STATUS                          352402
# SYMBOL                          355968
# TERMINATED                      355968
# DECIMALS                             0
# dtype: int64

# %%
print(labour6_df.isnull().sum())
# Out:
# REF_DATE                            0
# GEO                                 0
# DGUID                               0
# Immigrant status                    0
# Educational attainment              0
# Labour force characteristics        0
# Sex                                 0
# Age group                           0
# UOM                                 0
# UOM_ID                              0
# SCALAR_FACTOR                       0
# SCALAR_ID                           0
# VECTOR                              0
# COORDINATE                          0
# VALUE                             237
# STATUS                          29139
# SYMBOL                          29376
# TERMINATED                      29376
# DECIMALS                            0
# dtype: int64

# %%
print(labour7_df.isnull().sum())
# Out:
# REF_DATE                             0
# GEO                                  0
# DGUID                                0
# Immigrant status                     0
# Country of birth                     0
# Labour force characteristics         0
# Sex                                  0
# Age group                            0
# UOM                                  0
# UOM_ID                               0
# SCALAR_FACTOR                        0
# SCALAR_ID                            0
# VECTOR                               0
# COORDINATE                           0
# VALUE                             6674
# STATUS                          319630
# SYMBOL                          326304
# TERMINATED                      326304
# DECIMALS                             0
# dtype: int64

# %%
print(labour8_df.isnull().sum())
# Out:
# REF_DATE                            0
# GEO                                 0
# DGUID                               0
# Immigrant status                    0
# Country of birth                    0
# Labour force characteristics        0
# Sex                                 0
# Age group                           0
# UOM                                 0
# UOM_ID                              0
# SCALAR_FACTOR                       0
# SCALAR_ID                           0
# VECTOR                              0
# COORDINATE                          0
# VALUE                             498
# STATUS                          26430
# SYMBOL                          26928
# TERMINATED                      26928
# DECIMALS                            0
# dtype: int64

# %%
labour1a = labour1_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour1a
# Out:
#        REF_DATE                          GEO  Immigrant status  \
# 0        06-Mar                       Canada  Total population
# 1        06-Mar                       Canada  Total population
# 2        06-Mar                       Canada  Total population
# 3        06-Mar                       Canada  Total population
# 4        06-Mar                       Canada  Total population
# ...         ...                          ...               ...
# 395515   23-Apr  Vancouver, British Columbia    Born in Canada
# 395516   23-Apr  Vancouver, British Columbia    Born in Canada
# 395517   23-Apr  Vancouver, British Columbia    Born in Canada
# 395518   23-Apr  Vancouver, British Columbia    Born in Canada
# 395519   23-Apr  Vancouver, British Columbia    Born in Canada
#
#        Labour force characteristics          Age group         UOM  \
# 0                        Population  15 years and over     Persons
# 1                        Population     25 to 54 years     Persons
# ...

# %%
labour2a = labour2_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour2a
# Out:
#        REF_DATE                          GEO  Immigrant status  \
# 0          2006                       Canada  Total population
# 1          2006                       Canada  Total population
# 2          2006                       Canada  Total population
# 3          2006                       Canada  Total population
# 4          2006                       Canada  Total population
# ...         ...                          ...               ...
# 32635      2022  Vancouver, British Columbia    Born in Canada
# 32636      2022  Vancouver, British Columbia    Born in Canada
# 32637      2022  Vancouver, British Columbia    Born in Canada
# 32638      2022  Vancouver, British Columbia    Born in Canada
# 32639      2022  Vancouver, British Columbia    Born in Canada
#
#       Labour force characteristics          Age group         UOM  \
# 0                       Population  15 years and over     Persons
# 1                       Population     25 to 54 years     Persons
# ...

# %%
labour3a = labour3_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour3a
# Out:
#        REF_DATE     GEO  Immigrant status Labour force characteristics  \
# 0       2006-03  Canada  Total population                   Population
# 1       2006-03  Canada  Total population                   Population
# 2       2006-03  Canada  Total population                   Population
# 3       2006-03  Canada  Total population                   Population
# 4       2006-03  Canada  Total population                   Population
# ...         ...     ...               ...                          ...
# 148315  2023-04  Canada    Born in Canada              Employment rate
# 148316  2023-04  Canada    Born in Canada              Employment rate
# 148317  2023-04  Canada    Born in Canada              Employment rate
# 148318  2023-04  Canada    Born in Canada              Employment rate
# 148319  2023-04  Canada    Born in Canada              Employment rate
#
#                Sex          Age group         UOM SCALAR_FACTOR    VALUE
# ...

# %%
labour4a = labour4_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour4a
# Out:
#        REF_DATE     GEO  Immigrant status Labour force characteristics  \
# 0          2006  Canada  Total population                   Population
# 1          2006  Canada  Total population                   Population
# 2          2006  Canada  Total population                   Population
# 3          2006  Canada  Total population                   Population
# 4          2006  Canada  Total population                   Population
# ...         ...     ...               ...                          ...
# 12235      2022  Canada    Born in Canada              Employment rate
# 12236      2022  Canada    Born in Canada              Employment rate
# 12237      2022  Canada    Born in Canada              Employment rate
# 12238      2022  Canada    Born in Canada              Employment rate
# 12239      2022  Canada    Born in Canada              Employment rate
#
#               Sex          Age group         UOM SCALAR_FACTOR    VALUE
# ...

# %%
labour5a = labour5_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour5a
# Out:
#        REF_DATE     GEO  Immigrant status       Educational attainment  \
# 0       2006-03  Canada  Total population  Total, all education levels
# 1       2006-03  Canada  Total population  Total, all education levels
# 2       2006-03  Canada  Total population  Total, all education levels
# 3       2006-03  Canada  Total population  Total, all education levels
# 4       2006-03  Canada  Total population  Total, all education levels
# ...         ...     ...               ...                          ...
# 355963  2023-04  Canada    Born in Canada            University degree
# 355964  2023-04  Canada    Born in Canada            University degree
# 355965  2023-04  Canada    Born in Canada            University degree
# 355966  2023-04  Canada    Born in Canada            University degree
# 355967  2023-04  Canada    Born in Canada            University degree
#
#        Labour force characteristics         Sex          Age group  \
# ...

# %%
labour6a = labour6_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour6a
# Out:
#        REF_DATE     GEO  Immigrant status       Educational attainment  \
# 0          2006  Canada  Total population  Total, all education levels
# 1          2006  Canada  Total population  Total, all education levels
# 2          2006  Canada  Total population  Total, all education levels
# 3          2006  Canada  Total population  Total, all education levels
# 4          2006  Canada  Total population  Total, all education levels
# ...         ...     ...               ...                          ...
# 29371      2022  Canada    Born in Canada            University degree
# 29372      2022  Canada    Born in Canada            University degree
# 29373      2022  Canada    Born in Canada            University degree
# 29374      2022  Canada    Born in Canada            University degree
# 29375      2022  Canada    Born in Canada            University degree
#
#       Labour force characteristics         Sex          Age group         UOM  \
# ...

# %%
labour7a = labour7_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour7a
# Out:
#        REF_DATE     GEO  Immigrant status  Country of birth  \
# 0       2006-03  Canada  Total population  Total population
# 1       2006-03  Canada  Total population  Total population
# 2       2006-03  Canada  Total population  Total population
# 3       2006-03  Canada  Total population  Total population
# 4       2006-03  Canada  Total population  Total population
# ...         ...     ...               ...               ...
# 326299  2023-04  Canada    Born in Canada            Canada
# 326300  2023-04  Canada    Born in Canada            Canada
# 326301  2023-04  Canada    Born in Canada            Canada
# 326302  2023-04  Canada    Born in Canada            Canada
# 326303  2023-04  Canada    Born in Canada            Canada
#
#        Labour force characteristics         Sex          Age group  \
# 0                        Population  Both sexes  15 years and over
# 1                        Population  Both sexes     25 to 54 years
# ...

# %%
labour8a = labour8_df.drop(['DGUID','UOM_ID','SCALAR_ID','VECTOR','COORDINATE','DECIMALS','STATUS','SYMBOL','TERMINATED'], axis = 1)
labour8a
# Out:
#        REF_DATE     GEO  Immigrant status  Country of birth  \
# 0          2006  Canada  Total population  Total population
# 1          2006  Canada  Total population  Total population
# 2          2006  Canada  Total population  Total population
# 3          2006  Canada  Total population  Total population
# 4          2006  Canada  Total population  Total population
# ...         ...     ...               ...               ...
# 26923      2022  Canada    Born in Canada            Canada
# 26924      2022  Canada    Born in Canada            Canada
# 26925      2022  Canada    Born in Canada            Canada
# 26926      2022  Canada    Born in Canada            Canada
# 26927      2022  Canada    Born in Canada            Canada
#
#       Labour force characteristics         Sex          Age group         UOM  \
# 0                       Population  Both sexes  15 years and over     Persons
# 1                       Population  Both sexes     25 to 54 years     Persons
# ...

# %%
laboura = labour1a.dropna()
print(laboura.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Labour force characteristics    0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
labourb = labour2a.dropna()
print(labourb.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Labour force characteristics    0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
labourc = labour3a.dropna()
print(labourc.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Labour force characteristics    0
# Sex                             0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
labourd = labour4a.dropna()
print(labourd.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Labour force characteristics    0
# Sex                             0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
laboure = labour5a.dropna()
print(laboure.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Educational attainment          0
# Labour force characteristics    0
# Sex                             0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
labourf = labour6a.dropna()
print(labourf.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Educational attainment          0
# Labour force characteristics    0
# Sex                             0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
labourg = labour7a.dropna()
print(labourg.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Country of birth                0
# Labour force characteristics    0
# Sex                             0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
labourh = labour8a.dropna()
print(labourh.isnull().sum())
# Out:
# REF_DATE                        0
# GEO                             0
# Immigrant status                0
# Country of birth                0
# Labour force characteristics    0
# Sex                             0
# Age group                       0
# UOM                             0
# SCALAR_FACTOR                   0
# VALUE                           0
# dtype: int64

# %%
laboura
# Out:
#        REF_DATE                          GEO  Immigrant status  \
# 0        06-Mar                       Canada  Total population
# 1        06-Mar                       Canada  Total population
# 2        06-Mar                       Canada  Total population
# 3        06-Mar                       Canada  Total population
# 4        06-Mar                       Canada  Total population
# ...         ...                          ...               ...
# 395515   23-Apr  Vancouver, British Columbia    Born in Canada
# 395516   23-Apr  Vancouver, British Columbia    Born in Canada
# 395517   23-Apr  Vancouver, British Columbia    Born in Canada
# 395518   23-Apr  Vancouver, British Columbia    Born in Canada
# 395519   23-Apr  Vancouver, British Columbia    Born in Canada
#
#        Labour force characteristics          Age group         UOM  \
# 0                        Population  15 years and over     Persons
# 1                        Population     25 to 54 years     Persons
# ...

# %%
labourb
# Out:
#        REF_DATE                          GEO  Immigrant status  \
# 0          2006                       Canada  Total population
# 1          2006                       Canada  Total population
# 2          2006                       Canada  Total population
# 3          2006                       Canada  Total population
# 4          2006                       Canada  Total population
# ...         ...                          ...               ...
# 32635      2022  Vancouver, British Columbia    Born in Canada
# 32636      2022  Vancouver, British Columbia    Born in Canada
# 32637      2022  Vancouver, British Columbia    Born in Canada
# 32638      2022  Vancouver, British Columbia    Born in Canada
# 32639      2022  Vancouver, British Columbia    Born in Canada
#
#       Labour force characteristics          Age group         UOM  \
# 0                       Population  15 years and over     Persons
# 1                       Population     25 to 54 years     Persons
# ...

# %%
labourc
# Out:
#        REF_DATE     GEO  Immigrant status Labour force characteristics  \
# 0       2006-03  Canada  Total population                   Population
# 1       2006-03  Canada  Total population                   Population
# 2       2006-03  Canada  Total population                   Population
# 3       2006-03  Canada  Total population                   Population
# 4       2006-03  Canada  Total population                   Population
# ...         ...     ...               ...                          ...
# 148315  2023-04  Canada    Born in Canada              Employment rate
# 148316  2023-04  Canada    Born in Canada              Employment rate
# 148317  2023-04  Canada    Born in Canada              Employment rate
# 148318  2023-04  Canada    Born in Canada              Employment rate
# 148319  2023-04  Canada    Born in Canada              Employment rate
#
#                Sex          Age group         UOM SCALAR_FACTOR    VALUE
# ...

# %%
labourd
# Out:
#        REF_DATE     GEO  Immigrant status Labour force characteristics  \
# 0          2006  Canada  Total population                   Population
# 1          2006  Canada  Total population                   Population
# 2          2006  Canada  Total population                   Population
# 3          2006  Canada  Total population                   Population
# 4          2006  Canada  Total population                   Population
# ...         ...     ...               ...                          ...
# 12235      2022  Canada    Born in Canada              Employment rate
# 12236      2022  Canada    Born in Canada              Employment rate
# 12237      2022  Canada    Born in Canada              Employment rate
# 12238      2022  Canada    Born in Canada              Employment rate
# 12239      2022  Canada    Born in Canada              Employment rate
#
#               Sex          Age group         UOM SCALAR_FACTOR    VALUE
# ...

# %%
laboure
# Out:
#        REF_DATE     GEO  Immigrant status       Educational attainment  \
# 0       2006-03  Canada  Total population  Total, all education levels
# 1       2006-03  Canada  Total population  Total, all education levels
# 2       2006-03  Canada  Total population  Total, all education levels
# 3       2006-03  Canada  Total population  Total, all education levels
# 4       2006-03  Canada  Total population  Total, all education levels
# ...         ...     ...               ...                          ...
# 355963  2023-04  Canada    Born in Canada            University degree
# 355964  2023-04  Canada    Born in Canada            University degree
# 355965  2023-04  Canada    Born in Canada            University degree
# 355966  2023-04  Canada    Born in Canada            University degree
# 355967  2023-04  Canada    Born in Canada            University degree
#
#        Labour force characteristics         Sex          Age group  \
# ...

# %%
labourf
# Out:
#        REF_DATE     GEO  Immigrant status       Educational attainment  \
# 0          2006  Canada  Total population  Total, all education levels
# 1          2006  Canada  Total population  Total, all education levels
# 2          2006  Canada  Total population  Total, all education levels
# 3          2006  Canada  Total population  Total, all education levels
# 4          2006  Canada  Total population  Total, all education levels
# ...         ...     ...               ...                          ...
# 29371      2022  Canada    Born in Canada            University degree
# 29372      2022  Canada    Born in Canada            University degree
# 29373      2022  Canada    Born in Canada            University degree
# 29374      2022  Canada    Born in Canada            University degree
# 29375      2022  Canada    Born in Canada            University degree
#
#       Labour force characteristics         Sex          Age group         UOM  \
# ...

# %%
labourg
# Out:
#        REF_DATE     GEO  Immigrant status  Country of birth  \
# 0       2006-03  Canada  Total population  Total population
# 1       2006-03  Canada  Total population  Total population
# 2       2006-03  Canada  Total population  Total population
# 3       2006-03  Canada  Total population  Total population
# 4       2006-03  Canada  Total population  Total population
# ...         ...     ...               ...               ...
# 326299  2023-04  Canada    Born in Canada            Canada
# 326300  2023-04  Canada    Born in Canada            Canada
# 326301  2023-04  Canada    Born in Canada            Canada
# 326302  2023-04  Canada    Born in Canada            Canada
# 326303  2023-04  Canada    Born in Canada            Canada
#
#        Labour force characteristics         Sex          Age group  \
# 0                        Population  Both sexes  15 years and over
# 1                        Population  Both sexes     25 to 54 years
# ...

# %%
labourh
# Out:
#        REF_DATE     GEO  Immigrant status  Country of birth  \
# 0          2006  Canada  Total population  Total population
# 1          2006  Canada  Total population  Total population
# 2          2006  Canada  Total population  Total population
# 3          2006  Canada  Total population  Total population
# 4          2006  Canada  Total population  Total population
# ...         ...     ...               ...               ...
# 26923      2022  Canada    Born in Canada            Canada
# 26924      2022  Canada    Born in Canada            Canada
# 26925      2022  Canada    Born in Canada            Canada
# 26926      2022  Canada    Born in Canada            Canada
# 26927      2022  Canada    Born in Canada            Canada
#
#       Labour force characteristics         Sex          Age group         UOM  \
# 0                       Population  Both sexes  15 years and over     Persons
# 1                       Population  Both sexes     25 to 54 years     Persons
# ...

# %%
laboura.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFC by immigrant status, three-month moving average, unadjusted for seasonality.xlsx")

# %%
labourb.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFC by immigrant status.xlsx")

# %%
labourc.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFCoI by sex and age group, three-month moving average, unadjusted for seasonality.xlsx")

# %%
labourd.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFCoI by sex and age group.xlsx")

# %%
laboure.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFCoI by educational attainment, three-month moving average, unadjusted for seasonality.xlsx")

# %%
labourf.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFCoI by educational attainment.xlsx")

# %%
labourg.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFCoI by country of birth, three-month moving average, unadjusted for seasonality.xlsx")

# %%
labourh.to_excel("C:\\Users\\johns\\OneDrive\\Desktop\\labour force\\LFCoI by country of birth.xlsx")
